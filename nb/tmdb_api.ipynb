# %% [markdown]
# # Settings

# %%
# %pip install requests

# %%
import requests
import csv

# %%
API_KEY = "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMTFmNjE4MjQ4ZjQwNTJlYWRiNzYwMDNmYTg4MTdlOSIsIm5iZiI6MTc0NTgzMzgxOS40MDMsInN1YiI6IjY4MGY0ZjViNWE5Yjc4ZDI3MjgxNGY1MiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.oQoQehgwFwugiGFWE5v3JgUdIma-3eteDp3X34RanAk"

# %%
def get_popular_movies(page=1):
    url = f"https://api.themoviedb.org/3/movie/popular?language=en-US&page={page}"
    headers = {
        "accept": "application/json",
        "Authorization": API_KEY
        }
    return requests.get(url, headers=headers).json()

def get_movie_details(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"
    headers = {
        "accept": "application/json",
        "Authorization": API_KEY 
    }
    return requests.get(url, headers=headers).json()

def get_movie_credits(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=en-US"
    headers = {
        "accept": "application/json",
        "Authorization": API_KEY
        }
    return requests.get(url, headers=headers).json()

def get_movie_reviews(movie_id, page=1):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews?language=en-US&page={page}"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMTFmNjE4MjQ4ZjQwNTJlYWRiNzYwMDNmYTg4MTdlOSIsIm5iZiI6MTc0NTgzMzgxOS40MDMsInN1YiI6IjY4MGY0ZjViNWE5Yjc4ZDI3MjgxNGY1MiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.oQoQehgwFwugiGFWE5v3JgUdIma-3eteDp3X34RanAk"
    }
    return requests.get(url, headers=headers).json()

# %% [markdown]
# ### Get Popular Movies

# %%
data = get_popular_movies(100)#put page numbers 1~
print(data)
# Out:
# {'page': 100, 'results': [{'adult': False, 'backdrop_path': '/yQCaNJpqPtfMMvKt51rHghG1J2w.jpg', 'genre_ids': [12, 28, 53], 'id': 660, 'original_language': 'en', 'original_title': 'Thunderball', 'overview': 'A criminal organization has obtained two nuclear bombs and are asking for a 100 million pound ransom in the form of diamonds in seven days or they will use the weapons. The secret service sends James Bond to the Bahamas to once again save the world.', 'popularity': 10.8344, 'poster_path': '/wCc4qllaTDsQN8zgGkAgQrKO6N9.jpg', 'release_date': '1965-12-11', 'title': 'Thunderball', 'video': False, 'vote_average': 6.666, 'vote_count': 2390}, {'adult': False, 'backdrop_path': '/zSJT1sKGRKcmP4I9b8dIOuepw6I.jpg', 'genre_ids': [12, 28, 53, 14], 'id': 375588, 'original_language': 'en', 'original_title': 'Robin Hood', 'overview': 'A war-hardened Crusader and his Moorish commander mount an audacious revolt against the corrupt English crown.', 'popularity': 11.11, 'poster_path': '/AiRfixFcfTkNb
# ...

# %%
data['results'], print(len(data['results'])) #20 per pages
# Out:
# 20
# ([{'adult': False,
#    'backdrop_path': '/yQCaNJpqPtfMMvKt51rHghG1J2w.jpg',
#    'genre_ids': [12, 28, 53],
#    'id': 660,
#    'original_language': 'en',
#    'original_title': 'Thunderball',
#    'overview': 'A criminal organization has obtained two nuclear bombs and are asking for a 100 million pound ransom in the form of diamonds in seven days or they will use the weapons. The secret service sends James Bond to the Bahamas to once again save the world.',
#    'popularity': 10.8344,
#    'poster_path': '/wCc4qllaTDsQN8zgGkAgQrKO6N9.jpg',
#    'release_date': '1965-12-11',
#    'title': 'Thunderball',
#    'video': False,
#    'vote_average': 6.666,
#    'vote_count': 2390},
#   {'adult': False,
#    'backdrop_path': '/zSJT1sKGRKcmP4I9b8dIOuepw6I.jpg',
#    'genre_ids': [12, 28, 53, 14],
#    'id': 375588,
#    'original_language': 'en',
#    'original_title': 'Robin Hood',
# ...

# %% [markdown]
# ### Get Details : Plot/Genres/Adult/Runtime/Release_Date

# %%
movie_id = '660' #'822119'
details = get_movie_details(movie_id)
details
# Out:
# {'adult': False,
#  'backdrop_path': '/yQCaNJpqPtfMMvKt51rHghG1J2w.jpg',
#  'belongs_to_collection': {'id': 645,
#   'name': 'James Bond Collection',
#   'poster_path': '/ofwSiqOFShhunAIYYdSMHMJQSx2.jpg',
#   'backdrop_path': '/dOSECZImeyZldoq0ObieBE0lwie.jpg'},
#  'budget': 9000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 53, 'name': 'Thriller'}],
#  'homepage': 'https://mgm.com/movies/thunderball',
#  'id': 660,
#  'imdb_id': 'tt0059800',
#  'origin_country': ['GB'],
#  'original_language': 'en',
#  'original_title': 'Thunderball',
#  'overview': 'A criminal organization has obtained two nuclear bombs and are asking for a 100 million pound ransom in the form of diamonds in seven days or they will use the weapons. The secret service sends James Bond to the Bahamas to once again save the world.',
#  'popularity': 10.8344,
#  'poster_path': '/wCc4qllaTDsQN8zgGkAgQrKO6N9.jpg',
#  'production_companies': [{'id': 7576,
# ...

# %%
print(details.get('overview')) #plot
print(details['runtime'])
print(details['adult'])
genres = [genre['name'] for genre in details.get('genres', [])]
print(genres)
# Out:
# A criminal organization has obtained two nuclear bombs and are asking for a 100 million pound ransom in the form of diamonds in seven days or they will use the weapons. The secret service sends James Bond to the Bahamas to once again save the world.
# 130
# False
# ['Adventure', 'Action', 'Thriller']

# %% [markdown]
# ### Actors, Directors (Credits)

# %%
movie_id = '660' #'822119'
crews = get_movie_credits(movie_id)
crews['cast'][0]
# Out:
# {'adult': False,
#  'gender': 2,
#  'id': 738,
#  'known_for_department': 'Acting',
#  'name': 'Sean Connery',
#  'original_name': 'Sean Connery',
#  'popularity': 4.5732,
#  'profile_path': '/hbB676mW62gjsh0f51ICYE11niG.jpg',
#  'cast_id': 1,
#  'character': 'James Bond',
#  'credit_id': '52fe4265c3a36847f801b551',
#  'order': 0}

# %%
actors = []
for x in crews['cast']:
    if x['known_for_department'] == 'Acting':
        actors.append(x)
    else:
        print(x) #no directors sometimes
# Out:
# {'adult': False, 'gender': 2, 'id': 9951, 'known_for_department': 'Production', 'name': 'Kevin McClory', 'original_name': 'Kevin McClory', 'popularity': 0.1757, 'profile_path': None, 'cast_id': 52, 'character': 'Man Smoking at Nassau Casino (uncredited)', 'credit_id': '6003e8f1be4b36003c55019a', 'order': 26}

# %% [markdown]
# ### Reviews

# %%
get_movie_reviews('660')['results']
# Out:
# [{'author': 'John Chard',
#   'author_details': {'name': '',
#    'username': 'John Chard',
#    'avatar_path': '/utEXl2EDiXBK6f41wCLsvprvMg4.jpg',
#    'rating': 7.0},
# ...
